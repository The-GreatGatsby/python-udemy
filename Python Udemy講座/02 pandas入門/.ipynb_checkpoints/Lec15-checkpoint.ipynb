# %%
import numpy as np
from pandas import Series, DataFrame     #「Series」と「DataFrame」はそのまま使うことが多いので、個別にロード。
import pandas as pd

# %%
# NFLのデータをサンプルとして使います。
import webbrowser
website = 'http://en.wikipedia.org/wiki/NFL_win-loss_records'
webbrowser.open(website)
# Out:
# True

# %%
# 「pd.read_clipboard」で、コピーしているデータフレームを読み込む。
#  今回は、clipboardだとバグるので、csvで保存してから読み込む。
# pandasには「read_txt」はない。エクセルでcsvにしてから「read_csv」を使うしかない。
nfl_frame = pd.read_csv("NFLwiki.csv",sep=",")

# %%
nfl_frame
# Out:
#     Rank                     Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0      1           Dallas Cowboys  502   374     6  0.573              1960
# 1      2        Green Bay Packers  737   562    37  0.565              1921
# 2      3            Chicago Bears  749   579    42  0.562              1920
# 3      4           Miami Dolphins  445   351     4  0.559              1966
# 4      5  New England Patriots[b]  489   386     9  0.558              1960
# 5      6        Minnesota Vikings  470   390    10  0.546              1961
# 6      7         Baltimore Ravens  190   161     1  0.541              1996
# 7      8          New York Giants  687   585    33  0.539              1925
# 8      9           Denver Broncos  470   404    10  0.537              1960
# 9     10      San Francisco 49ers  528   460    14  0.534              1950
# 10    11      Pittsburgh Steelers  614   538    20  0.532              1933
# ...

# %%
# 「.columns」で列名を出力。
nfl_frame.columns
# Out:
# Index(['Rank', 'Team', 'Won', 'Lost', 'Tied', 'Pct.', 'First NFL Season',
#        'Total Games', 'Division'],
#       dtype='object')

# %%
nfl_frame['First NFL Season']
# Out:
# 0     1960
# 1     1921
# 2     1920
# 3     1966
# 4     1960
# 5     1961
# 6     1996
# 7     1925
# 8     1960
# 9     1950
# 10    1933
# 11    1960
# 12    1953
# 13    1960
# 14    1976
# 15    1932
# 16    1995
# 17    1960
# 18    1937
# 19    1950
# 20    1933
# 21    1960
# 22    1960
# 23    1930
# 24    1968
# 25    1960
# 26    1995
# 27    1967
# 28    1966
# 29    2002
# 30    1920
# 31    1976
# Name: First NFL Season, dtype: int64

# %%
# オブジェクトの属性のような書き方も可能
nfl_frame.Team
# Out:
# 0              Dallas Cowboys
# 1           Green Bay Packers
# 2               Chicago Bears
# 3              Miami Dolphins
# 4     New England Patriots[b]
# 5           Minnesota Vikings
# 6            Baltimore Ravens
# 7             New York Giants
# 8              Denver Broncos
# 9         San Francisco 49ers
# 10        Pittsburgh Steelers
# 11            Oakland Raiders
# 12      Indianapolis Colts[c]
# 13         Kansas City Chiefs
# 14           Seattle Seahawks
# 15        Washington Redskins
# 16          Carolina Panthers
# 17       Los Angeles Chargers
# 18           Los Angeles Rams
# 19           Cleveland Browns
# 20        Philadelphia Eagles
# 21           Tennessee Titans
# 22              Buffalo Bills
# 23              Detroit Lions
# 24         Cincinnati Bengals
# 25              New York Jets
# 26       Jacksonville Jaguars
# 27         New Orleans Saints
# 28            Atlanta Falcons
# 29             Houston Texans
# 30          Arizona Cardinals
# ...

# %%
# 特定のカラムで新しいDataFrameを作る
DataFrame(nfl_frame,columns=['Team','First Season','Total Games'])
# Out:
#                        Team  First Season Total Games
# 0            Dallas Cowboys           NaN         882
# 1         Green Bay Packers           NaN       1,336
# 2             Chicago Bears           NaN       1,370
# 3            Miami Dolphins           NaN         800
# 4   New England Patriots[b]           NaN         884
# 5         Minnesota Vikings           NaN         870
# 6          Baltimore Ravens           NaN         352
# 7           New York Giants           NaN       1,305
# 8            Denver Broncos           NaN         884
# 9       San Francisco 49ers           NaN       1,002
# 10      Pittsburgh Steelers           NaN       1,172
# 11          Oakland Raiders           NaN         884
# 12    Indianapolis Colts[c]           NaN         966
# 13       Kansas City Chiefs           NaN         884
# 14         Seattle Seahawks           NaN         660
# 15      Washington Redskins           NaN       1,202
# ...

# %%
DataFrame(nfl_frame,columns=['Team','First Season','Total Games','Stadium'])
# Out:
#                        Team  First Season Total Games  Stadium
# 0            Dallas Cowboys           NaN         882      NaN
# 1         Green Bay Packers           NaN       1,336      NaN
# 2             Chicago Bears           NaN       1,370      NaN
# 3            Miami Dolphins           NaN         800      NaN
# 4   New England Patriots[b]           NaN         884      NaN
# 5         Minnesota Vikings           NaN         870      NaN
# 6          Baltimore Ravens           NaN         352      NaN
# 7           New York Giants           NaN       1,305      NaN
# 8            Denver Broncos           NaN         884      NaN
# 9       San Francisco 49ers           NaN       1,002      NaN
# 10      Pittsburgh Steelers           NaN       1,172      NaN
# 11          Oakland Raiders           NaN         884      NaN
# 12    Indianapolis Colts[c]           NaN         966      NaN
# 13       Kansas City Chiefs           NaN         884      NaN
# ...

# %%
# 先頭だけを表示
nfl_frame.head()
# Out:
#    Rank                     Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1           Dallas Cowboys  502   374     6  0.573              1960
# 1     2        Green Bay Packers  737   562    37  0.565              1921
# 2     3            Chicago Bears  749   579    42  0.562              1920
# 3     4           Miami Dolphins  445   351     4  0.559              1966
# 4     5  New England Patriots[b]  489   386     9  0.558              1960
#
#   Total Games   Division
# 0         882   NFC East
# 1       1,336  NFC North
# 2       1,370  NFC North
# 3         800   AFC East
# 4         884   AFC East

# %%
#最後だけを表示
nfl_frame.tail()
# Out:
#     Rank                  Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 27    28    New Orleans Saints  349   432     5  0.447              1967
# 28    29       Atlanta Falcons  351   443     6  0.443              1966
# 29    30        Houston Texans  110   146     0  0.430              2002
# 30    31     Arizona Cardinals  550   740    40  0.429              1920
# 31    32  Tampa Bay Buccaneers  255   404     1  0.387              1976
#
#    Total Games   Division
# 27         786  NFC South
# 28         790  NFC South
# 29         256  AFC South
# 30       1,330   NFC West
# 31         660  NFC South

# %%
# indexを使って、行を取り出せる
nfl_frame.ix[3]
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# Rank                             4
# Team                Miami Dolphins
# Won                            445
# Lost                           351
# Tied                             4
# Pct.                         0.559
# First NFL Season              1966
# Total Games                    800
# Division                  AFC East
# Name: 3, dtype: object

# %%
# 列全体に値を代入
nfl_frame['Stadium']="Levi's Stadium" #文字列内に「'」があるので、全体は「”」で囲む

# %%
nfl_frame
# Out:
#     Rank                     Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0      1           Dallas Cowboys  502   374     6  0.573              1960
# 1      2        Green Bay Packers  737   562    37  0.565              1921
# 2      3            Chicago Bears  749   579    42  0.562              1920
# 3      4           Miami Dolphins  445   351     4  0.559              1966
# 4      5  New England Patriots[b]  489   386     9  0.558              1960
# 5      6        Minnesota Vikings  470   390    10  0.546              1961
# 6      7         Baltimore Ravens  190   161     1  0.541              1996
# 7      8          New York Giants  687   585    33  0.539              1925
# 8      9           Denver Broncos  470   404    10  0.537              1960
# 9     10      San Francisco 49ers  528   460    14  0.534              1950
# 10    11      Pittsburgh Steelers  614   538    20  0.532              1933
# ...

# %%
# 長さが合っていれば、列への代入が可能。
nfl_frame["Stadium"] = np.arange(32)
nfl_frame
# Out:
#     Rank                     Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0      1           Dallas Cowboys  502   374     6  0.573              1960
# 1      2        Green Bay Packers  737   562    37  0.565              1921
# 2      3            Chicago Bears  749   579    42  0.562              1920
# 3      4           Miami Dolphins  445   351     4  0.559              1966
# 4      5  New England Patriots[b]  489   386     9  0.558              1960
# 5      6        Minnesota Vikings  470   390    10  0.546              1961
# 6      7         Baltimore Ravens  190   161     1  0.541              1996
# 7      8          New York Giants  687   585    33  0.539              1925
# 8      9           Denver Broncos  470   404    10  0.537              1960
# 9     10      San Francisco 49ers  528   460    14  0.534              1950
# 10    11      Pittsburgh Steelers  614   538    20  0.532              1933
# ...

# %%
# SeriesをDataFrameに追加する
stadiums = Series(["Levi's Stadium","AT&T Stadium"],index=[4,0])

# %%
stadiums
# Out:
# 4    Levi's Stadium
# 0      AT&T Stadium
# dtype: object

# %%
nfl_frame['Stadium']=stadiums
nfl_frame
# Out:
#     Rank                     Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0      1           Dallas Cowboys  502   374     6  0.573              1960
# 1      2        Green Bay Packers  737   562    37  0.565              1921
# 2      3            Chicago Bears  749   579    42  0.562              1920
# 3      4           Miami Dolphins  445   351     4  0.559              1966
# 4      5  New England Patriots[b]  489   386     9  0.558              1960
# 5      6        Minnesota Vikings  470   390    10  0.546              1961
# 6      7         Baltimore Ravens  190   161     1  0.541              1996
# 7      8          New York Giants  687   585    33  0.539              1925
# 8      9           Denver Broncos  470   404    10  0.537              1960
# 9     10      San Francisco 49ers  528   460    14  0.534              1950
# 10    11      Pittsburgh Steelers  614   538    20  0.532              1933
# ...

# %%
# 列を消すことも可能
del nfl_frame['Stadium']
nfl_frame
# Out:
#     Rank                     Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0      1           Dallas Cowboys  502   374     6  0.573              1960
# 1      2        Green Bay Packers  737   562    37  0.565              1921
# 2      3            Chicago Bears  749   579    42  0.562              1920
# 3      4           Miami Dolphins  445   351     4  0.559              1966
# 4      5  New England Patriots[b]  489   386     9  0.558              1960
# 5      6        Minnesota Vikings  470   390    10  0.546              1961
# 6      7         Baltimore Ravens  190   161     1  0.541              1996
# 7      8          New York Giants  687   585    33  0.539              1925
# 8      9           Denver Broncos  470   404    10  0.537              1960
# 9     10      San Francisco 49ers  528   460    14  0.534              1950
# 10    11      Pittsburgh Steelers  614   538    20  0.532              1933
# ...

# %%
# 辞書からDataFramesを作ることもできます。
data = {'City':['SF','LA','NYC'],
        'Population':[837000,3880000,8400000]}

city_frame = DataFrame(data)

#Show
city_frame
# Out:
#   City  Population
# 0   SF      837000
# 1   LA     3880000
# 2  NYC     8400000

# %%
# pandas.DataFrameの機能の全体は、Webで確認できます。
website = 'http://pandas.pydata.org/pandas-docs/dev/generated/pandas.DataFrame.html'
webbrowser.open(website)
# Out:
# True
